# %%
def add(a, b, c=100):
        return a + b + c

print(add(1, 2))
# Out:
# 103

# %%
courses = {
    "HUDT1001": "Introduction to Humanities and Digital Technologies",
    "HUDT1002": "Essential Methods in Humanitites and Digitial Technologies"
}

if "hudt1001" in courses:
    print(courses["hudt1001"])
else:
    print("Course not found.")
# Out:
# Course not found.
