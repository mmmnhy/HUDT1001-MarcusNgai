# %%
def function_name():
  print("This is a function.")

function_name()
# Out:
# This is a function.

# %%
def add(a, b):
   return a + b

result1 = add(3, 5)
print(f"result1: {result1}")
# Out:
# result1: 8

# %%
def
